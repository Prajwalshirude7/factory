# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
telemetry = pd.read_csv("C:\\Users\\Prajwal\\factoryguard\\data\\raw\\Microsoft Azure Predictive Maintenance\\PdM_telemetry.csv")
failures = pd.read_csv("C:\\Users\\Prajwal\\factoryguard\\data\\raw\\Microsoft Azure Predictive Maintenance\\PdM_failures.csv")
errors = pd.read_csv("C:\\Users\\Prajwal\\factoryguard\\data\\raw\\Microsoft Azure Predictive Maintenance\\PdM_errors.csv")
maint = pd.read_csv("C:\\Users\\Prajwal\\factoryguard\\data\\raw\\Microsoft Azure Predictive Maintenance\\PdM_maint.csv")
machines = pd.read_csv("C:\\Users\\Prajwal\\factoryguard\\data\\raw\\Microsoft Azure Predictive Maintenance\\PdM_machines.csv")

telemetry["datetime"] = pd.to_datetime(telemetry["datetime"])
failures["datetime"] = pd.to_datetime(failures["datetime"])

# %%
telemetry.shape
telemetry.info()
telemetry.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 876100 entries, 0 to 876099
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   datetime   876100 non-null  datetime64[ns]
#  1   machineID  876100 non-null  int64
#  2   volt       876100 non-null  float64
#  3   rotate     876100 non-null  float64
#  4   pressure   876100 non-null  float64
#  5   vibration  876100 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 40.1 MB
#                   datetime      machineID           volt         rotate  \
# count               876100  876100.000000  876100.000000  876100.000000
# mean   2015-07-02 18:00:00      50.500000     170.777736     446.605119
# min    2015-01-01 06:00:00       1.000000      97.333604     138.432075
# 25%    2015-04-02 12:00:00      25.750000     160.304927     412.305714
# 50%    2015-07-02 18:00:00      50.500000     170.607338     447.558150
# ...

# %%
telemetry.isnull().sum()
# Out:
# datetime     0
# machineID    0
# volt         0
# rotate       0
# pressure     0
# vibration    0
# dtype: int64

# %%
failures["failure"].value_counts()

sns.countplot(x="failure",data=failures)
plt.title("Failure distribution")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(telemetry["vibration"])
plt.title("Vibration Trend")
plt.show()

# %%
sns.heatmap(telemetry[["volt","rotate","pressure","vibration"]].corr(),annot=True)
# Out:
# <Axes: >

# %%
machines["model"].value_counts()
# Out:
# model
# model3    35
# model4    32
# model2    17
# model1    16
# Name: count, dtype: int64
